# %% [markdown]
# <a href="https://colab.research.google.com/github/allfed/CropOpt/blob/standardize/notebooks/yield_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rerun these each time you open Colab

# %%
# !rm -rf allfed-integrated-model/
# !git clone -b main https://github.com/allfed/allfed-integrated-model.git

# %%
# This adds the Python files in our repo to our path so we can import
# them

import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# !pip install PuLP
# !pip install numpy
# !pip install matplotlib

os.chdir('/content/allfed-integrated-model/notebooks/')

# %% [markdown]
# # Optimizer demo

# %% [markdown]
# The purpose of this file is to allow researchers to run the optimizer with differing assumptions. Please reach out to morgan@allfed.info if you have questions about this code.
#
# This will recreate all graphs accessible in the recently submitted paper that were generated by the optimization model.
#
# First, let's import the Optimizer, which runs through the code to optimize the minimum people fed of calories, fat, and protein.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path)
import numpy as np
# Out:
# /home/dmrivers/Code

# %% [markdown]
# Now, we run the no resilient food case, generating the total food production with resilient foods.

# %%
# %cd ../src/scenarios
# %run run_model_no_resilient_foods.py
# %cd ../../scripts
# Out:
# /home/dmrivers/Code/allfed-integrated-model/src/scenarios
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# False
# Nutrients with constraining values are: ['protein']
# Estimated percent people fed is 77.42756%
# 77.42756
#
# Estimated Kcals/capita/day, no resilient foods, no waste
# 1625.97876
#
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# False
# Nutrients with constraining values are: ['protein']
# Estimated percent people fed is 62.335916%
# 62.335916
# Estimated Kcals/capita/day, no resilient foods, minus waste & delayed halt of nonhuman consumption
# 1309.054236
#
# saved figure 1ab

# %% [markdown]
# Run the case with resilient foods. This will take a minute to converge on the diet.

# %%
# %cd ../../scripts
# Out:
# /home/dmrivers/Code/allfed-integrated-model/scripts

# %%
# %cd ../src/scenarios
# %run run_model_with_resilient_foods.py
# %cd ../../scripts
# Out:
# /home/dmrivers/Code/allfed-integrated-model/src/scenarios
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 155.11631%
# 155.11631
#
# no waste estimated people fed (kcals/capita/day)
# 3257.44251
#
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 155.11631%
# 155.11631
# Food available after waste, feed ramp down and biofuel ramp down, with resilient foods (kcals per capita per day)
# 3257.44251
#
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 129.1873%
# 129.1873
# Calculating 2100 calorie diet, excess feed to animals
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 129.1873%
# 129.1873
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 126.87988%
# 126.87988
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 123.82887%
# 123.82887
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 120.88958%
# 120.88958
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 118.13671%
# 118.13671
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 115.45287%
# 115.45287
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 112.94311%
# 112.94311
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 110.46534%
# 110.46534
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 108.06948%
# 108.06948
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 105.83832%
# 105.83832
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 103.76338%
# 103.76338
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 103.34388%
# 103.34388
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 103.06547%
# 103.06547
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 102.81608%
# 102.81608
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 102.58584%
# 102.58584
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 102.37395%
# 102.37395
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 102.17635%
# 102.17635
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.99367%
# 101.99367
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.82362%
# 101.82362
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.66634%
# 101.66634
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.52227%
# 101.52227
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.38769%
# 101.38769
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.26227%
# 101.26227
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.14819%
# 101.14819
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 101.04044%
# 101.04044
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.94259%
# 100.94259
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.85039%
# 100.85039
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.76482%
# 100.76482
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.68646%
# 100.68646
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.61396%
# 100.61396
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.54749%
# 100.54749
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.48535%
# 100.48535
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.42737%
# 100.42737
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.37406%
# 100.37406
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.32432%
# 100.32432
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.27853%
# 100.27853
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.2349%
# 100.2349
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.19665%
# 100.19665
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.16052%
# 100.16052
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.12652%
# 100.12652
# Diet computation complete
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 1492.822
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
# WARNING: MAKE SURE YOU ARE NOT RUNNING BY COUNTRY!!!!
#
#
#
#
# the reason no to, is that we're dividing by total crop
# area, and that won't work on a by-country basis.
# We need to use by-country fraction of total crop area
# if we're adding greenhouses.
#
#
#
#
#
# False
# Nutrients with constraining values are: ['fat', 'kcals']
# Estimated percent people fed is 100.09431%
# 100.09431
# saved figure 2abcd
# Diet computation complete
# /home/dmrivers/Code/allfed-integrated-model/scripts

# %% [markdown]
# Run the baseline scenario in 2020

# %%
# %cd ../src/scenarios/
# %run run_model_baseline.py
# %cd ../../scripts
# Out:
# [Errno 2] No such file or directory: '../src/scenarios/'
# /home/dmrivers/Code/allfed-integrated-model/src/scenarios
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 351.9979999999998
# False
# Nutrients with constraining values are: ['fat']
# Estimated percent people fed is 209.76951%
# 209.76951
#
# Maximum usable kcals/capita/day 2020, no waste, primary production
# 4405.15971
#
# self.POP_BILLIONS
# 7.8
# protein 1000 tons BASELINE_CROP_PROTEIN / 1e3
# 350000.0
# billion kcals ANNUAL_YIELD * 4e6 / 1e9
# 14615040.0
# self.OG_FRACTION_PROTEIN
# 0.022271577771939045
# stores_at_sim_start
# 351.9979999999998
# False
# Nutrients with constraining values are: ['kcals']
# Estimated percent people fed is 99.403461%
# 99.403461
# saved figure s1abcd
# [Errno 2] No such file or directory: '../scripts'
# /home/dmrivers/Code/allfed-integrated-model/src/scenarios

# %% [markdown]
# Run the Monte Carlo scenarios. We choose the "True" value for run_all_scenarios, which loads existing data from the monte carlo and plots it.

# %%
# %cd ../src/scenarios
from src.scenarios.monte_carlo import MonteCarlo
# Out:
# /home/dmrivers/Code/allfed-integrated-model/src/scenarios

# %%
MonteCarlo.run_all_scenarios(10000, 1000, True, True)
# Out:
# Computing input variables
# Monte Carlo variables
# saved figure s1
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 95% lower
# 2147.315555
# 95% upper
# 3491.7608115384605
# /home/dmrivers/Code/allfed-integrated-model/src/utilities/plotter.py:448: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# saved figure 3ab

# %% [markdown]
# Import analysis data saved in previous runs, and plot the result for primary production

# %%
from src.utilities.plotter import Plotter
resilient_food_primary_production_analysis = np.load(
    '../../data/resilient_food_primary_analysis.npy',
    allow_pickle=True).item()

no_resilient_food_primary_production_analysis = np.load(
    '../../data/no_resilient_food_primary_analysis.npy',
    allow_pickle=True).item()

Plotter.plot_fig_s2abcd(
    resilient_food_primary_production_analysis,
    no_resilient_food_primary_production_analysis,
    48,
    72)
# Out:
# saved figure s2abcd
