# %% [markdown]
# <a href="https://colab.research.google.com/github/allfed/CropOpt/blob/standardize/scripts/recreate_paper_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing the repository and all its dependencies

# %%
import sys
import os
if 'google.colab' in sys.modules:
    # Get the repository and install everything if you are running this from a Colab notebook.
    # !pip install git+https://github.com/allfed/allfed-integrated-model.git
    # !pip install python-pptx
    # !pip install pulp
else:
    # If you are running this locally you should install the dependencies in your own virtual environment.
    # change to the directory where the package is located and install it
    os.chdir("..")
    # !pip install -e .

# %% [markdown]
# # Recreating the figures of the paper

# %% [markdown]
# This will recreate all graphs accessible in the recently submitted paper to Nature Foods that were generated by the integrated model.
# Please reach out to morgan@allfed.info if you have questions about this code.

# %% [markdown]
# ## Figure 1

# %%
from src.scenarios.create_figure_1ab import main as figure_1
# This may take a while to run
figure_1(sys.argv[1:])

# %% [markdown]
# ## Figure 2

# %%
from src.scenarios.create_figure_2abcde import main as figure2
figure2()

# %% [markdown]
# ## Figure 3

# %%
from src.scenarios.create_figure_3abcd import main as figure3
figure3()
